# %%
import os
import glob
import numpy as np
from tensorflow.keras import layers
from tensorflow import keras 
import tensorflow as tf

# %%
# %%time
from keras import models
from keras import layers
from keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()

network = models.Sequential();
network.add(layers.Dense(200,activation = 'relu', input_shape = (28*28,)));
#network.add(layers.Dense(256,activation ='relu'));
network.add(layers.Dense(10,activation = 'softmax'))
# Out:
# Using TensorFlow backend.
# CPU times: user 386 ms, sys: 89.6 ms, total: 476 ms
# Wall time: 476 ms

# %%
network.compile(optimizer='rmsprop',
                loss = 'categorical_crossentropy',
                metrics = ['accuracy'])

# %%
train_images = train_images.reshape((60000, 28 * 28))
train_images = train_images.astype('float32') / 255
test_images = test_images.reshape((10000, 28 * 28))
test_images = test_images.astype('float32') / 255

# %%
from keras.utils import to_categorical
train_labels = to_categorical(train_labels)
test_labels = to_categorical(test_labels)

# %%
# %%time
network.fit(train_images,train_labels,epochs=5,batch_size=128)
# Out:
# Epoch 1/5
# 60000/60000 [==============================] - 3s 50us/step - loss: 0.3103 - acc: 0.9134
# Epoch 2/5
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.1424 - acc: 0.9586
# Epoch 3/5
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0977 - acc: 0.9712
# Epoch 4/5
# 60000/60000 [==============================] - 3s 48us/step - loss: 0.0731 - acc: 0.9786
# Epoch 5/5
# 60000/60000 [==============================] - 3s 49us/step - loss: 0.0582 - acc: 0.9827
# CPU times: user 20.8 s, sys: 2.08 s, total: 22.9 s
# Wall time: 14.9 s
